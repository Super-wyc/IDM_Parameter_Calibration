# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np

# %%
class Data_process():
    def __init__(self, path, target_lane:int = 2, following_time:float = 15) -> None:
        '''
        数据筛选类
        参数：
        traget_lane：目标车道
        following_ti0me：跟随时间限制
        '''
        self.path = path
        self.data = pd.read_csv(path)
        self.lane = target_lane
        self.time = following_time

    def lane_selecter(self) -> pd.DataFrame:
        self.data = self.data[self.data['laneId'] == self.lane]
        return self.data
    
    def car_following_selecter(self) -> pd.DataFrame:
        self.data = self.data[self.data["followingId"] != 0]
        return self.data
    
    def time_selecter(self) -> pd.DataFrame:
        self.lane_selecter()
        self.car_following_selecter()
        time_selected = self.data.groupby(['id', 'followingId']).count()['frame']
        time_selected = time_selected[time_selected > self.time * 25].sort_values(ascending=False)
        return time_selected

    def distance_selector(self) -> dict:
        '''
        返回值：
        以跟车对为键，片段为值的字典
        '''
        temp = self.time_selecter()
        self.__init__(self.path, self.lane, self.time)
        self.lane_selecter()
        distance = {}
        for car_pair in temp.index:
            front_car = self.data[(self.data['id']==car_pair[0]) & (self.data['followingId']==car_pair[1])]
            following_car = self.data[self.data['id']==car_pair[1]]
            same_frame = following_car[following_car['frame'].isin(front_car['frame'])]
            d = abs(same_frame['x'].reset_index(drop=True)-front_car[front_car['frame'].isin(same_frame['frame'])]['x'].reset_index(drop=True))
            d.rename('distance', inplace=True)
            d = pd.concat([d, same_frame['x'].reset_index(drop=True), 
                           front_car[front_car['frame'].isin(same_frame['frame'])]['x'].reset_index(drop=True),
                           same_frame['frame'].reset_index(drop=True)], ignore_index=True, axis=1)
            d.columns = ['distance',  'following_x', 'front_x', 'frame']
            d['front_speed'] = abs(d['front_x'].diff() * 25)
            d['following_speed'] = abs(d['following_x'].diff() * 25)
            d['front_id'] = [car_pair[0]] * len(d)
            d['following_id'] = [car_pair[1]] * len(d)
            d = d.bfill()
            if sum((d['distance'] >=5) & (d['distance'] <= 120)) > self.time * 25:
                distance[car_pair] = d
            else:
                continue
        return distance
    
    def plot_following(self, pair:tuple=(215, 217))  -> None:
        plt.rcParams['font.sans-serif'] = ['SimHei']
        df = self.distance_selector()[pair]
        plt.plot((df['frame'] / 25), df['front_x'], label=f'前导车辆-{pair[0]}', color='#6495ed')
        plt.plot((df['frame'] / 25), df['following_x'], label=f'跟随车辆-{pair[1]}', color='#e76a83')
        plt.legend()
        return None
    
    def data_merge(self) -> tuple:
        '''
        数据匹配
        输出属性：x、width、speed、class、feature
        返回值：元组 0:合并之后完整的DataFrame, 1:合并之和同之前的字典
        '''
        pattern_ = ".+\d{2}_"
        get_path = re.search(pattern_, self.path).group()
        tracks_data = pd.read_csv(fr"{get_path}tracksMeta.csv")
        data = self.distance_selector()
        for pair in data.keys():
            data[pair]['front_width'] = tracks_data[tracks_data['id'] == pair[0]]['width'].repeat(len(data[pair])).reset_index(drop=True)
            data[pair]['following_width'] = tracks_data[tracks_data['id'] == pair[1]]['width'].repeat(len(data[pair])).reset_index(drop=True)
            data[pair]['front_class'] = tracks_data[tracks_data['id'] == pair[0]]['class'].repeat(len(data[pair])).reset_index(drop=True)
            data[pair]['following_class'] = tracks_data[tracks_data['id'] == pair[1]]['class'].repeat(len(data[pair])).reset_index(drop=True)
            data[pair]['front_feature'] = np.full([len(data[pair]), 1], np.nan)
            data[pair]['following_feature'] = np.full([len(data[pair]), 1], np.nan)
        mix_data = pd.DataFrame([])
        for piece in data.values():
            mix_data = pd.concat([piece, mix_data], ignore_index=True)
        return mix_data, data
    
    def position_trans(self) -> tuple:
        '''
        x坐标归一化
        返回值：归一后的x坐标(tuple, 0:front, 1:following)
        '''
        x_data = self.distance_selector()
        data = self.data_merge()[1]
        for pair in x_data.keys():
            x_data[pair].drop(index=[0], inplace=True)
            data[pair].drop(index=[0], inplace=True)
            x_data[pair]['front_x'] = x_data[pair]['front_x'].apply(lambda x: abs(x-x_data[pair]['front_x'][1]))
            x_data[pair]['following_x'] = x_data[pair]['following_x'].apply(lambda x: abs(x-x_data[pair]['following_x'][1]))
            data[pair]['front_x'] =  x_data[pair]['front_x']
            data[pair]['following_x'] =  x_data[pair]['following_x']
        mix_data_trans = pd.DataFrame([])
        for piece in data.values():
            mix_data_trans = pd.concat([piece, mix_data_trans], ignore_index=True)
        return mix_data_trans, data

    def save_csv(self, path:str = 'dataset', how='single') -> pd.DataFrame:  # path只需要传入文件夹的路径即可，不需要对文件命名
        pattern = '\d{2}_tracks\.csv'
        name = re.search(pattern, self.path).group()
        data = self.position_trans()
        if how == "mix":
            data[0].to_csv(f"{path}\car_following_{name}")
        elif how == "single":
            data_dict = self.position_trans()[1]
            for key in data_dict.keys():
                data_dict[key].to_csv(rf"{path}\{key}_{name}")
        return (lambda how: data[0] if how=="mix" else data_dict)(how)

# %%
t = Data_process(r'E:\Traffic courses\Grade2b\Traffic simulation technology\Parameter calibration\HighD Data\data\01_tracks.csv')
t.distance_selector()[t.time_selecter().index[1]]
x=t.data_merge()[0]
t.position_trans()[1]
t.save_csv()
# Out:
# {(540,
#   542):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       47.08         0.00     0.00  10765        22.50            20.50
#  2       47.13         0.84     0.89  10766        22.25            21.00
#  3       47.16         1.70     1.78  10767        22.25            21.50
#  4       47.17         2.58     2.67  10768        22.25            22.00
#  5       47.19         3.46     3.57  10769        22.50            22.00
#  ..        ...          ...      ...    ...          ...              ...
#  417     42.10       367.09   362.11  11181        22.00            21.50
#  418     42.12       367.96   363.00  11182        22.25            21.75
#  419     42.14       368.83   363.89  11183        22.25            21.75
#  420     42.15       369.71   364.78  11184        22.25            22.00
#  421     42.17       370.58   365.67  11185        22.25            21.75
#
#       front_id  following_id  front_width  following_width front_class  \
#  1         540           542        16.78             5.96       Truck
#  2         540           542        16.78             5.96       Truck
#  3         540           542        16.78             5.96       Truck
#  4         540           542        16.78             5.96       Truck
#  5         540           542        16.78             5.96       Truck
#  ..        ...           ...          ...              ...         ...
#  417       540           542        16.78             5.96       Truck
#  418       540           542        16.78             5.96       Truck
#  419       540           542        16.78             5.96       Truck
#  420       540           542        16.78             5.96       Truck
#  421       540           542        16.78             5.96       Truck
#
#      following_class  front_feature  following_feature
#  1               Car            NaN                NaN
#  2               Car            NaN                NaN
#  3               Car            NaN                NaN
#  4               Car            NaN                NaN
#  5               Car            NaN                NaN
#  ..              ...            ...                ...
#  417             Car            NaN                NaN
#  418             Car            NaN                NaN
#  419             Car            NaN                NaN
#  420             Car            NaN                NaN
#  421             Car            NaN                NaN
#
#  [421 rows x 14 columns],
#  (215,
#   217):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       33.24         0.00     0.00   4550        23.75            22.00
#  2       33.27         0.91     0.94   4551        23.50            22.75
#  3       33.30         1.82     1.88   4552        23.50            22.75
#  4       33.32         2.75     2.83   4553        23.75            23.25
#  5       33.30         3.70     3.76   4554        23.25            23.75
#  ..        ...          ...      ...    ...          ...              ...
#  417     26.16       386.35   379.27   4966        22.00            22.75
#  418     26.11       387.27   380.14   4967        21.75            23.00
#  419     26.08       388.18   381.02   4968        22.00            22.75
#  420     26.03       389.10   381.89   4969        21.75            23.00
#  421     25.98       390.02   382.76   4970        21.75            23.00
#
#       front_id  following_id  front_width  following_width front_class  \
#  1         215           217        16.73             4.55       Truck
#  2         215           217        16.73             4.55       Truck
#  3         215           217        16.73             4.55       Truck
#  4         215           217        16.73             4.55       Truck
#  5         215           217        16.73             4.55       Truck
#  ..        ...           ...          ...              ...         ...
#  417       215           217        16.73             4.55       Truck
#  418       215           217        16.73             4.55       Truck
#  419       215           217        16.73             4.55       Truck
#  420       215           217        16.73             4.55       Truck
#  421       215           217        16.73             4.55       Truck
#
#      following_class  front_feature  following_feature
#  1               Car            NaN                NaN
#  2               Car            NaN                NaN
#  3               Car            NaN                NaN
#  4               Car            NaN                NaN
#  5               Car            NaN                NaN
#  ..              ...            ...                ...
#  417             Car            NaN                NaN
#  418             Car            NaN                NaN
#  419             Car            NaN                NaN
#  420             Car            NaN                NaN
#  421             Car            NaN                NaN
#
#  [421 rows x 14 columns],
#  (295,
#   298):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       32.75         0.00     0.00   6072        23.25            19.25
#  2       32.88         0.81     0.94   6073        23.50            20.25
#  3       32.98         1.65     1.88   6074        23.50            21.00
#  4       33.08         2.50     2.83   6075        23.75            21.25
#  5       33.18         3.36     3.79   6076        24.00            21.50
#  ..        ...          ...      ...    ...          ...              ...
#  413     23.05       376.82   367.12   6484        21.25            22.00
#  414     23.03       377.70   367.98   6485        21.50            22.00
#  415     23.01       378.58   368.84   6486        21.50            22.00
#  416     22.99       379.46   369.70   6487        21.50            22.00
#  417     22.98       380.33   370.56   6488        21.50            21.75
#
#       front_id  following_id  front_width  following_width front_class  \
#  1         295           298         3.84             4.45         Car
#  2         295           298         3.84             4.45         Car
#  3         295           298         3.84             4.45         Car
#  4         295           298         3.84             4.45         Car
#  5         295           298         3.84             4.45         Car
#  ..        ...           ...          ...              ...         ...
#  413       295           298         3.84             4.45         Car
#  414       295           298         3.84             4.45         Car
#  415       295           298         3.84             4.45         Car
#  416       295           298         3.84             4.45         Car
#  417       295           298         3.84             4.45         Car
#
#      following_class  front_feature  following_feature
#  1               Car            NaN                NaN
#  2               Car            NaN                NaN
#  3               Car            NaN                NaN
#  4               Car            NaN                NaN
#  5               Car            NaN                NaN
#  ..              ...            ...                ...
#  413             Car            NaN                NaN
#  414             Car            NaN                NaN
#  415             Car            NaN                NaN
#  416             Car            NaN                NaN
#  417             Car            NaN                NaN
#
#  [417 rows x 14 columns],
#  (532,
#   537):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       39.80         0.00     0.00  10692        22.00            20.50
#  2       39.84         0.85     0.89  10693        22.25            21.25
#  3       39.86         1.71     1.77  10694        22.00            21.50
#  4       39.89         2.58     2.67  10695        22.50            21.75
#  5       39.88         3.47     3.55  10696        22.00            22.25
#  ..        ...          ...      ...    ...          ...              ...
#  406     41.42       356.15   357.77  11097        22.25            22.00
#  407     41.44       357.02   358.66  11098        22.25            21.75
#  408     41.44       357.90   359.54  11099        22.00            22.00
#  409     41.46       358.77   360.43  11100        22.25            21.75
#  410     41.48       359.64   361.32  11101        22.25            21.75
#
#       front_id  following_id  front_width  following_width front_class  \
#  1
Truck
#
#      following_class  front_feature  following_feature
#  1               Car            NaN                NaN
#  2               Car            NaN                NaN
#  3               Car            NaN                NaN
#  4               Car            NaN                NaN
#  5               Car            NaN                NaN
#  ..              ...            ...                ...
#  402             Car            NaN                NaN
#  403             Car            NaN                NaN
#  404             Car            NaN                NaN
#  405             Car            NaN                NaN
#  406             Car            NaN                NaN
#
#  [406 rows x 14 columns],
#  (617,
#   619):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       43.97         0.00     0.00  12705        23.25            20.25
#  2       44.06         0.85     0.94  12706        23.50            21.25
#  3       44.12         1.73     1.88  12707        23.50            22.00
#  4       44.16         2.63     2.82  12708        23.50            22.50
#  5       44.18         3.54     3.75  12709        23.25            22.75
#  ..        ...          ...      ...    ...          ...              ...
#  401     36.91       377.70   370.64  13105        22.75            23.00
#  402     36.90       378.63   371.56  13106        23.00            23.25
#  403     36.90       379.55   372.48  13107        23.00            23.00
#  404     36.89       380.47   373.39  13108        22.75            23.00
#  405     36.91       381.37   374.31  13109        23.00            22.50
#
#       front_id  following_id  front_width  following_width front_class  \
#  1         617           619         18.7             4.45       Truck
#  2         617           619         18.7             4.45       Truck
#  3         617           619         18.7             4.45       Truck
#  4         617           619         18.7             4.45       Truck
#  5         617           619         18.7             4.45       Truck
#  ..        ...           ...          ...              ...         ...
#  401       617           619         18.7             4.45       Truck
#  402       617           619         18.7             4.45       Truck
#  403       617           619         18.7             4.45       Truck
#  404       617           619         18.7             4.45       Truck
#  405       617           619         18.7             4.45       Truck
#
#      following_class  front_feature  following_feature
#  1               Car            NaN                NaN
#  2               Car            NaN                NaN
#  3               Car            NaN                NaN
#  4               Car            NaN                NaN
#  5               Car            NaN                NaN
#  ..              ...            ...                ...
#  401             Car            NaN                NaN
#  402             Car            NaN                NaN
#  403             Car            NaN                NaN
#  404             Car            NaN                NaN
#  405             Car            NaN                NaN
#
#  [405 rows x 14 columns],
#  (537,
#   540):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       29.71         0.00     0.00  10726        22.00            21.25
#  2       29.72         0.88     0.89  10727        22.25            22.00
#  3       29.72         1.78     1.79  10728        22.50            22.50
#  4       29.71         2.68     2.68  10729        22.25            22.50
#  5       29.70         3.58     3.57  10730        22.25            22.50
#  ..        ...          ...      ...    ...          ...              ...
#  399     31.63       347.60   349.52  11124        22.25            21.25
#  400     31.64       348.48   350.41  11125        22.25            22.00
#  401     31.65       349.34   351.28  11126        21.75            21.50
#  402     31.66       350.21   352.16  11127        22.00            21.75
#  403     31.66       351.07   353.02  11128        21.50            21.50
#
#       front_id  following_id  front_width  following_width front_class  \
#  1         537           540        16.67            16.78       Truck
#  2         537           540        16.67            16.78       Truck
#  3         537           540        16.67            16.78       Truck
#  4         537           540        16.67            16.78       Truck
#  5         537           540        16.67            16.78       Truck
#  ..        ...           ...          ...              ...         ...
#  399       537           540        16.67            16.78       Truck
#  400       537           540        16.67            16.78       Truck
#  401       537           540        16.67            16.78       Truck
#  402       537           540        16.67            16.78       Truck
#  403       537           540        16.67            16.78       Truck
#
#      following_class  front_feature  following_feature
#  1             Truck            NaN                NaN
#  2             Truck            NaN                NaN
#  3             Truck            NaN                NaN
#  4             Truck            NaN                NaN
#  5             Truck            NaN                NaN
#  ..              ...            ...                ...
#  399           Truck            NaN                NaN
#  400           Truck            NaN                NaN
#  401           Truck            NaN                NaN
#  402           Truck            NaN                NaN
#  403           Truck            NaN                NaN
#
#  [403 rows x 14 columns],
#  (943,
#   945):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1
Car
#
#      following_class  front_feature  following_feature
#  1               Car            NaN                NaN
#  2               Car            NaN                NaN
#  3               Car            NaN                NaN
#  4               Car            NaN                NaN
#  5               Car            NaN                NaN
#  ..              ...            ...                ...
#  389             Car            NaN                NaN
#  390             Car            NaN                NaN
#  391             Car            NaN                NaN
#  392             Car            NaN                NaN
#  393             Car            NaN                NaN
#
#  [393 rows x 14 columns],
#  (664,
#   666):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       30.85         0.00     0.00  13985        24.25            22.00
#  2       30.93         0.90     0.98  13986        24.50            22.50
#  3       30.97         1.82     1.94  13987        24.00            23.00
#  4       30.98         2.77     2.90  13988        24.00            23.75
#  5       30.99         3.72     3.86  13989        24.00            23.75
#  ..        ...          ...      ...    ...          ...              ...
#  388     33.24       369.55   371.94  14372        24.00            24.00
#  389     33.24       370.51   372.90  14373        24.00            24.00
#  390     33.24       371.47   373.86  14374        24.00            24.00
#  391     33.25       372.42   374.82  14375        24.00            23.75
#  392     33.26       373.38   375.79  14376        24.25            24.00
#
#       front_id  following_id  front_width  following_width front_class  \
#  1         664           666        14.75            11.82         Car
#  2         664           666        14.75            11.82         Car
#  3         664           666        14.75            11.82         Car
#  4         664           666        14.75            11.82         Car
#  5         664           666        14.75            11.82         Car
#  ..        ...           ...          ...              ...         ...
#  388       664           666        14.75            11.82         Car
#  389       664           666        14.75            11.82         Car
#  390       664           666        14.75            11.82         Car
#  391       664           666        14.75            11.82         Car
#  392       664           666        14.75            11.82         Car
#
#      following_class  front_feature  following_feature
#  1             Truck            NaN                NaN
#  2             Truck            NaN                NaN
#  3             Truck            NaN                NaN
#  4             Truck            NaN                NaN
#  5             Truck            NaN                NaN
#  ..              ...            ...                ...
#  388           Truck            NaN                NaN
#  389           Truck            NaN                NaN
#  390           Truck            NaN                NaN
#  391           Truck            NaN                NaN
#  392           Truck            NaN                NaN
#
#  [392 rows x 14 columns],
#  (73,
#   75):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       27.10         0.00     0.00   1401        25.25            24.25
#  2       27.11         1.00     1.01   1402        25.25            25.00
#  3       27.10         2.02     2.02   1403        25.25            25.50
#  4       27.08         3.05     3.03   1404        25.25            25.75
#  5       27.02         4.10     4.02   1405        24.75            26.25
#  ..        ...          ...      ...    ...          ...              ...
#  387     22.86       382.23   377.99   1787        24.00            23.75
#  388     22.87       383.18   378.95   1788        24.00            23.75
#  389     22.89       384.12   379.91   1789        24.00            23.50
#  390     22.90       385.07   380.87   1790        24.00            23.75
#  391     22.92       386.01   381.83   1791        24.00            23.50
#
#       front_id  following_id  front_width  following_width front_class  \
#  1          73            75         3.94             3.74         Car
#  2          73            75         3.94             3.74         Car
#  3          73            75         3.94             3.74         Car
#  4          73            75         3.94             3.74         Car
#  5          73            75         3.94             3.74         Car
#  ..        ...           ...          ...              ...         ...
#  387        73            75         3.94             3.74         Car
#  388        73            75         3.94             3.74         Car
#  389        73            75         3.94             3.74         Car
#  390        73            75         3.94             3.74         Car
#  391        73            75         3.94             3.74         Car
#
#      following_class  front_feature  following_feature
#  1               Car            NaN                NaN
#  2               Car            NaN                NaN
#  3               Car            NaN                NaN
#  4               Car            NaN                NaN
#  5               Car            NaN                NaN
#  ..              ...            ...                ...
#  387             Car            NaN                NaN
#  388             Car            NaN                NaN
#  389             Car            NaN                NaN
#  390             Car            NaN                NaN
#  391             Car            NaN                NaN
#
#  [391 rows x 14 columns],
#  (72,
#   73):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1
50
#
#       front_id  following_id  front_width  following_width front_class  \
#  1         207           210        16.98            16.27       Truck
#  2         207           210        16.98            16.27       Truck
#  3         207           210        16.98            16.27       Truck
#  4         207           210        16.98            16.27       Truck
#  5         207           210        16.98            16.27       Truck
#  ..        ...           ...          ...              ...         ...
#  375       207           210        16.98            16.27       Truck
#  376       207           210        16.98            16.27       Truck
#  377       207           210        16.98            16.27       Truck
#  378       207           210        16.98            16.27       Truck
#  379       207           210        16.98            16.27       Truck
#
#      following_class  front_feature  following_feature
#  1             Truck            NaN                NaN
#  2             Truck            NaN                NaN
#  3             Truck            NaN                NaN
#  4             Truck            NaN                NaN
#  5             Truck            NaN                NaN
#  ..              ...            ...                ...
#  375           Truck            NaN                NaN
#  376           Truck            NaN                NaN
#  377           Truck            NaN                NaN
#  378           Truck            NaN                NaN
#  379           Truck            NaN                NaN
#
#  [379 rows x 14 columns],
#  (632,
#   634):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       39.41         0.00     0.00  13065        24.25            22.25
#  2       39.44         0.93     0.96  13066        24.00            23.25
#  3       39.46         1.88     1.93  13067        24.25            23.75
#  4       39.46         2.85     2.90  13068        24.25            24.25
#  5       39.45         3.84     3.88  13069        24.50            24.75
#  ..        ...          ...      ...    ...          ...              ...
#  374     46.29       353.16   360.04  13438        23.75            23.50
#  375     46.32       354.09   361.00  13439        24.00            23.25
#  376     46.35       355.02   361.96  13440        24.00            23.25
#  377     46.38       355.95   362.92  13441        24.00            23.25
#  378     46.40       356.88   363.87  13442        23.75            23.25
#
#       front_id  following_id  front_width  following_width front_class  \
#  1         632           634         4.55             4.95         Car
#  2         632           634         4.55             4.95         Car
#  3         632           634         4.55             4.95         Car
#  4         632           634         4.55             4.95         Car
#  5         632           634         4.55             4.95         Car
#  ..        ...           ...          ...              ...         ...
#  374       632           634         4.55             4.95         Car
#  375       632           634         4.55             4.95         Car
#  376       632           634         4.55             4.95         Car
#  377       632           634         4.55             4.95         Car
#  378       632           634         4.55             4.95         Car
#
#      following_class  front_feature  following_feature
#  1               Car            NaN                NaN
#  2               Car            NaN                NaN
#  3               Car            NaN                NaN
#  4               Car            NaN                NaN
#  5               Car            NaN                NaN
#  ..              ...            ...                ...
#  374             Car            NaN                NaN
#  375             Car            NaN                NaN
#  376             Car            NaN                NaN
#  377             Car            NaN                NaN
#  378             Car            NaN                NaN
#
#  [378 rows x 14 columns],
#  (1009,
#   1011):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       33.02         0.00     0.00  21711        24.50            22.75
#  2       33.07         0.94     0.99  21712        24.75            23.50
#  3       33.08         1.90     1.96  21713        24.25            24.00
#  4       33.07         2.89     2.94  21714        24.50            24.75
#  5       33.07         3.87     3.92  21715        24.50            24.50
#  ..        ...          ...      ...    ...          ...              ...
#  374     24.84       374.75   366.57  22084        24.25            25.75
#  375     24.78       375.78   367.54  22085        24.25            25.75
#  376     24.74       376.80   368.52  22086        24.50            25.50
#  377     24.70       377.81   369.49  22087        24.25            25.25
#  378     24.67       378.82   370.47  22088        24.50            25.25
#
#       front_id  following_id  front_width  following_width front_class  \
#  1        1009          1011         4.75             4.65         Car
#  2        1009          1011         4.75             4.65         Car
#  3        1009          1011         4.75             4.65         Car
#  4        1009          1011         4.75             4.65         Car
#  5        1009          1011         4.75             4.65         Car
#  ..        ...           ...          ...              ...         ...
#  374      1009          1011         4.75             4.65         Car
#  375      1009          1011         4.75             4.65         Car
#  376      1009          1011         4.75             4.65         Car
#  377      1009          1011         4.75             4.65         Car
#  378      1009          1011         4.75             4.65         Car
#
#      following_class  front_feature  following_feature
#  1               Car            NaN                NaN
#  2               Car            NaN                NaN
#  3               Car            NaN                NaN
#  4               Car            NaN                NaN
#  5               Car            NaN                NaN
#  ..              ...            ...                ...
#  374             Car            NaN                NaN
#  375             Car            NaN                NaN
#  376             Car            NaN                NaN
#  377             Car            NaN                NaN
#  378             Car            NaN                NaN
#
#  [378 rows x 14 columns],
#  (744,
#   746):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       45.41         0.00     0.00  15732        24.00            22.00
#  2       45.47         0.91     0.97  15733        24.25            22.75
#  3       45.50         1.85     1.94  15734        24.25            23.50
#  4       45.51         2.82     2.92  15735        24.50            24.25
#  5       45.54         3.77     3.90  15736        24.50            23.75
#  ..        ...          ...      ...    ...          ...              ...
#  372     44.87       360.17   359.63  16103        24.25            23.75
#  373     44.89       361.12   360.60  16104        24.25            23.75
#  374     44.89       362.09   361.57  16105        24.25            24.25
#  375     44.90       363.05   362.54  16106        24.25            24.00
#  376     44.89       364.03   363.51  16107        24.25            24.50
#
#       front_id  following_id  front_width  following_width front_class  \
#  1         744           746         18.9            12.03       Truck
#  2         744           746         18.9            12.03       Truck
#  3         744           746         18.9            12.03       Truck
#  4         744           746         18.9            12.03       Truck
#  5         744           746         18.9            12.03       Truck
#  ..        ...           ...          ...              ...         ...
#  372       744           746         18.9            12.03       Truck
#  373       744           746         18.9            12.03       Truck
#  374       744           746         18.9            12.03       Truck
#  375       744           746         18.9            12.03       Truck
#  376       744           746         18.9            12.03       Truck
#
#      following_class  front_feature  following_feature
#  1             Truck            NaN                NaN
#  2             Truck            NaN                NaN
#  3             Truck            NaN                NaN
#  4             Truck            NaN                NaN
#  5             Truck            NaN                NaN
#  ..              ...            ...                ...
#  372           Truck            NaN                NaN
#  373           Truck            NaN                NaN
#  374           Truck            NaN                NaN
#  375           Truck            NaN                NaN
#  376           Truck            NaN                NaN
#
#  [376 rows x 14 columns],
#  (62,
#   64):      distance  following_x  front_x  frame  front_speed  following_speed  \
#  1       47.76         0.00     0.00   1242        24.50            22.00
#  2       47.82         0.93     0.99   1243        24.75            23.25
#  3       47.85         1.89     1.98   1244        24.75            24.00
#  4       47.87         2.85     2.96   1245        24.50            24.00
#  5       47.89         3.82     3.95   1246        24.75            24.25
#  ..        ...          ...      ...    ...          ...              ...
#  371     45.68       366.09   364.01   1612        24.50            24.50
#  372     45.65       367.09   364.98   1613        24.25            25.00
#  373     45.65       368.07   365.96   1614        24.50            24.50
#  374     45.62       369.07   366.93   1615        24.25            25.00
#  375     45.61       370.06   367.91   1616        24.50            24.75
#
#       front_id  following_id  front_width  following_width front_class  \
#  1          62            64        11.93             4.35       Truck
#  2          62            64        11.93             4.35       Truck
#  3          62            64        11.93             4.35       Truck
#  4          62            64        11.93             4.35       Truck
#  5          62            64        11.93             4.35       Truck
#  ..        ...           ...          ...              ...         ...
#  371        62            64        11.93             4.35       Truck
#  372        62            64        11.93             4.35       Truck
#  373        62            64        11.93             4.35       Truck
#  374        62            64        11.93             4.35       Truck
#  375        62            64        11.93             4.35       Truck
#
#      following_class  front_feature  following_feature
#  1               Car            NaN                NaN
#  2               Car            NaN                NaN
#  3               Car            NaN                NaN
#  4               Car            NaN                NaN
#  5               Car            NaN                NaN
#  ..              ...            ...                ...
#  371             Car            NaN                NaN
#  372             Car            NaN                NaN
#  373             Car            NaN                NaN
#  374             Car            NaN                NaN
#  375             Car            NaN                NaN
#
#  [375 rows x 14 columns]}
